# %% [markdown]
# #Importing Libraries

# %%
# importing libraries

import pandas as pd
import numpy as np
import plotly.express as px 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# set_option is use to display the number of rows and columns. By Default maximum number of columns displayed is 20 and maximum number of rows is 60. 'None' is set to display maximum number of columns or rows.
#
# print pd.get_option('display.max_columns')  -> 20  [output]<br>
# print pd.get_option('display.max_rows')  -> 60  [output]

# %%
pd.set_option('display.max_columns', None) #displaying all the columns

# %% [markdown]
# #Reading Data

# %%
df = pd.read_csv('/content/Teleco_Churn.csv') #importing the dataset

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df.info() #getting the datatypes for the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# There are 7043 Rows and 21 Columns.<br>
# There are 17 Categorical Columns.<br>
# There are 3 Numerical Columns.<br>
# And Finally Churn column to see whether customer is churned or not (Yes or No).

# %%
df.describe() #describing the numerical dataset
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# df.describe(include = 'O') -> it pulls out the objects dtypes attributes and shows their count/frequency/max/quartiles.

# %%
df.describe(include = 'O') #describing the object datatypes
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# ###Duplicate Values

# %%
df.duplicated().sum() # finding duplicate values
# Out:
# 0

# %% [markdown]
# ###Missing Values

# %%
df.isnull().sum() # finding null values
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ###Renaming Columns for Ease to code

# %%
df.columns = df.columns.str.lower() # renaming the columns for ease of code

# %%
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %% [markdown]
# ###Total Charges

# %%
df['totalcharges'].describe()
# Out:
# count     7043
# unique    6531
# top
# freq        11
# Name: totalcharges, dtype: object

# %%
df['totalcharges'] = df['totalcharges'].astype(float) # converting all rows to type float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-278852d47ae3> in <module>
# ----> 1 df['totalcharges'] = df['totalcharges'].astype(float)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %% [markdown]
# This indicates that some empty values are stored as empty spaces. Let’s transform the feature into a numerical format while equating these empty string spaces as NaN as follows:

# %%
len(df[df['totalcharges'] == ' ']) #finding frequency of type string
# Out:
# 11

# %%
df = df[df['totalcharges'] != ' '] #removing rows with datatype string

# %%
len(df[df['totalcharges'] == ' ']) #checking if all the rows are removed
# Out:
# 0

# %%
df['totalcharges'].dtype # checking the datatype of the column totalcharges
# Out:
# dtype('O')

# %%
df['totalcharges'] = pd.to_numeric(df['totalcharges'])
# Out:
# <ipython-input-19-e7fc3f859af8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['totalcharges'] = pd.to_numeric(df['totalcharges'])

# %%
df['totalcharges'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ###Senior Citizen

# %%
df['seniorcitizen'].dtype
# Out:
# dtype('int64')

# %%
df['seniorcitizen'] = df['seniorcitizen'].astype('object')
# Out:
# <ipython-input-22-82b084d75199>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['seniorcitizen'] = df['seniorcitizen'].astype('object')

# %%
df['seniorcitizen'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ###Drop Unnecessary Column

# %%
df.drop('customerid', axis = 1, inplace = True) #dropping customer id column
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#    gender seniorcitizen partner dependents  tenure phoneservice  \
# 0  Female             0     Yes         No       1           No
# 1    Male             0      No         No      34          Yes
# 2    Male             0      No         No       2          Yes
# 3    Male             0      No         No      45           No
# 4  Female             0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity onlinebackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   deviceprotection techsupport streamingtv streamingmovies        contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# ###Churn

# %%
df['churn'].replace(to_replace = 'Yes', value = 1, inplace = True) #replacing churn Yes with 1
df['churn'].replace(to_replace = 'No',  value = 0, inplace = True) #replacing churn No with 0
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df['churn'].value_counts(normalize = True) #finding count of churn Yes and No
# Out:
# 0    0.734215
# 1    0.265785
# Name: churn, dtype: float64

# %%
sns.countplot(data = df, x = 'churn')
# Out:
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %% [markdown]
# ###Data Exploratrion

# %% [markdown]
# ####1.Numerical Features

# %%
numerical_data = df[['tenure', 'monthlycharges', 'totalcharges']] #separating the numerical data

# %%
numerical_data.describe() #describing the numerical data
# Out:
#             tenure  monthlycharges  totalcharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
churn_data = df[df.churn == 1] 
not_churn_data = df[df.churn == 0]

# %%
#defining a function for plotting a specific feature with churn and not churn data

def numeric_plot(feature):
    fig, ax = plt.subplots(1, 2, figsize = (12, 4))
    sns.histplot(data = churn_data, x = feature, ax = ax[0], color = 'green', kde = True)
    sns.histplot(data = not_churn_data, x = feature, ax = ax[1], color = 'red', kde = True)
    ax[0].set_xlabel(feature, size = 13)
    ax[0].set_ylabel('number of customers', size = 13)
    ax[0].set_title('Churn', size = 13)
    ax[1].set_xlabel(feature, size = 13)
    ax[1].set_ylabel('number of customers', size = 13)
    ax[1].set_title('Not Churn', size = 13)
    plt.show()

# %%
numeric_plot('tenure')

# %%
numeric_plot('monthlycharges')

# %%
numeric_plot('totalcharges')

# %%
#defining a function for exploration of numerical columns with respect to churn and no churn

def exploring_numerical_features(data, col):
    fig = px.histogram(data, x = col, color = 'churn', title = f'Total Churn by {col.title()}', width = 700, height = 600)
    fig.show()

# %%
exploring_numerical_features(df, 'tenure')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_numerical_features(df, 'monthlycharges')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_numerical_features(df, 'totalcharges')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
#
# 1. Customers who do not churn, tend to stay for a longer tenure with the company.
# 2. Recent customers are more probable to churn
# 3. Customers with higher MonthlyCharges are also more probable to churn

# %% [markdown]
# ####2. Categorical Features

# %%
df.describe(include = 'O')
# Out:
#        gender  seniorcitizen partner dependents phoneservice multiplelines  \
# count    7032           7032    7032       7032         7032          7032
# unique      2              2       2          2            2             3
# top      Male              0      No         No          Yes            No
# freq     3549           5890    3639       4933         6352          3385
#
#        internetservice onlinesecurity onlinebackup deviceprotection  \
# count             7032           7032         7032             7032
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3497         3087             3094
#
#        techsupport streamingtv streamingmovies        contract  \
# count         7032        7032            7032            7032
# unique           3           3               3               3
# ...

# %% [markdown]
# #####2.1- Gender and SeniorCitizen (Age)

# %%
gender_data = df['gender'].value_counts(normalize = True)
gender_data
# Out:
# Male      0.504693
# Female    0.495307
# Name: gender, dtype: float64

# %%
px.pie(values = gender_data.values, names = gender_data.index, title = 'Gender', height = 400, width = 400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
seniorcitizen_data = df['seniorcitizen'].value_counts(normalize = True)
seniorcitizen_data
# Out:
# 0    0.8376
# 1    0.1624
# Name: seniorcitizen, dtype: float64

# %%
px.pie(values = seniorcitizen_data.values, names = seniorcitizen_data.index, title = 'SeniorCitizen', height = 400, width = 400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.groupby(['gender', 'seniorcitizen'])['churn'].mean().reset_index()
# Out:
#    gender  seniorcitizen     churn
# 0  Female              0  0.239794
# 1  Female              1  0.422535
# 2    Male              0  0.233277
# 3    Male              1  0.411150

# %%
plt.figure(figsize = (7, 6))
sns.barplot(data = df, x = 'gender', y = 'churn', hue = 'seniorcitizen', ci = None, palette = 'Set1');

# %% [markdown]
# From the plots above we can conclude that:
# 1. About half of the customers in our data set are male while the other half are female.
# 2. Gender doesn't affect churn.
# 3. Senior citizens are only 16% of customers, but they have a much higher churn rate of 42% and 23% for non-seniors.

# %% [markdown]
# #####2.2- Partner and Dependents

# %%
partner_data = df['partner'].value_counts(normalize = True)
partner_data
# Out:
# No     0.517491
# Yes    0.482509
# Name: partner, dtype: float64

# %%
px.pie(values = partner_data.values, names = partner_data.index, title = 'Partner', height = 400, width = 400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dependents_data = df['dependents'].value_counts(normalize = True)
dependents_data
# Out:
# No     0.701507
# Yes    0.298493
# Name: dependents, dtype: float64

# %%
px.pie(values = dependents_data.values, names = dependents_data.index, title = 'Dependents', height = 400, width = 400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.groupby(['partner', 'dependents'])['churn'].mean().reset_index()
# Out:
#   partner dependents     churn
# 0      No         No  0.342378
# 1      No        Yes  0.214485
# 2     Yes         No  0.254083
# 3     Yes        Yes  0.143103

# %%
plt.figure(figsize = (7, 6))
sns.barplot(data = df, x = 'partner', y = 'churn', hue = 'dependents', ci = None, palette = 'Set1');

# %% [markdown]
# From the plots above we can conclude that:
# 1. About 50% of the customers have a partner, while only 30% of the total customers have dependents.
# 2. Customers that doesn't have partners are more probable to churn.
# 3. Customers without dependents are also more probable to churn.

# %% [markdown]
# #####2.3- Phone Service and Multiple Lines

# %%
df['phoneservice'].value_counts(normalize = True)
# Out:
# Yes    0.903299
# No     0.096701
# Name: phoneservice, dtype: float64

# %%
fig = px.bar(df['phoneservice'].value_counts(normalize = True), height = 500, width = 500, 
            color = df['phoneservice'].value_counts(normalize = True).index)
fig.update(layout_showlegend = False)
fig.update_layout(xaxis_title = 'Phone Service', yaxis_title = 'Percentage of Customers')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['multiplelines'].value_counts(normalize = True)
# Out:
# No                  0.481371
# Yes                 0.421928
# No phone service    0.096701
# Name: multiplelines, dtype: float64

# %%
fig = px.bar(df['multiplelines'].value_counts(normalize = True), height = 500, width = 500, 
             color = df['multiplelines'].value_counts(normalize = True).index)
fig.update(layout_showlegend = False)
fig.update_layout(xaxis_title = 'Phone Service', yaxis_title = 'Percentage of Customers')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.groupby(['multiplelines'])['churn'].mean()
# Out:
# multiplelines
# No                  0.250812
# No phone service    0.250000
# Yes                 0.286485
# Name: churn, dtype: float64

# %%
df.groupby(['phoneservice'])['churn'].mean()
# Out:
# phoneservice
# No     0.250000
# Yes    0.267475
# Name: churn, dtype: float64

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 6))
for i, col in enumerate(['phoneservice', 'multiplelines']):
    sns.barplot(data = df, x = col, y = 'churn', ci = None, ax = ax[i], palette = 'Set1')
plt.tight_layout()
plt.show()

# %%
px.histogram(df, x = 'multiplelines', y = 'monthlycharges', color = 'churn', height = 500, width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Few customers doesn't have phone service.
# 2. Customers who use multiple lines pay more monthly charges than the rest.
# 3. Customers with multiple lines have a slightly higher churn rate.

# %% [markdown]
# #####2.4- Internet Services

# %%
df['internetservice'].value_counts(normalize = True)
# Out:
# Fiber optic    0.440273
# DSL            0.343572
# No             0.216155
# Name: internetservice, dtype: float64

# %%
fig = px.bar(df['internetservice'].value_counts(normalize = True), height = 500, width = 500, 
             color = df['internetservice'].value_counts(normalize = True).index)
fig.update(layout_showlegend = False)
fig.update_layout(xaxis_title = 'Internet Service', yaxis_title = 'Percentage of Customers')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.groupby('internetservice')['churn'].mean()
# Out:
# internetservice
# DSL            0.189983
# Fiber optic    0.418928
# No             0.074342
# Name: churn, dtype: float64

# %%
fig = px.bar(df.groupby('internetservice')['churn'].mean(), height = 500, width = 600, 
             color = df.groupby('internetservice')['churn'].mean().index)
fig.update(layout_showlegend = False)
fig.update_layout(xaxis_title = 'Internet Service', yaxis_title = 'Percentage of Churn')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df, x = 'internetservice', y = 'monthlycharges', color = 'churn', height = 500, width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Clients without internet have a very low churn rate.
# 2. Customers who use fiber pay more monthly charges than they use DSL connections.
# 3. Customers with fiber are more probable to churn.

# %% [markdown]
# ######2.5- Addtional Services
# ######There are six additional services for customers with internet ('onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies')

# %%
def exploring_addtional_services(feature):
    fig = px.bar(df[feature].value_counts(normalize = True), height = 500, width = 500, 
                 color = df[feature].value_counts(normalize = True).index)
    
    fig.update(layout_showlegend = False)
    fig.update_layout(xaxis_title = feature, yaxis_title = 'Percentage of Customers')
    fig.show()
    
    
    
def exploring_addtional_services_churn(feature): 
    fig = px.bar(df.groupby(feature)['churn'].mean(), height = 500, width = 600, 
                 color = df.groupby(feature)['churn'].mean().index)
    
    fig.update(layout_showlegend = False)
    fig.update_layout(xaxis_title = feature, yaxis_title = 'Percentage of Churn')
    fig.show()

# %% [markdown]
# ######2.5.1- Online Security

# %%
exploring_addtional_services('onlinesecurity')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('onlinesecurity')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Customers who don't subscribe to the online security service are more probable to churn.

# %% [markdown]
# ######2.5.2- Tech Support

# %%
exploring_addtional_services('techsupport')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('techsupport')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Customers who don't subscribe to the tech support service are more probable to churn.

# %% [markdown]
# ######2.5.3- Online Backup

# %%
exploring_addtional_services('onlinebackup')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('onlinebackup')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Customers who don't subscribe to the online backup service are more probable to churn.

# %% [markdown]
# ######2.5.4- Device Protection

# %%
exploring_addtional_services('deviceprotection')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('deviceprotection')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Customers who don't subscribe to the device protection service are more probable to churn.

# %% [markdown]
# ######2.5.5- Streaming TV

# %%
exploring_addtional_services('streamingtv')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('streamingtv')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Churn is not affected by streaming tv services.

# %% [markdown]
# ######2.5.6- Streaming Movies

# %%
exploring_addtional_services('streamingmovies')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('streamingmovies')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Churn is not affected by streaming movies services.

# %% [markdown]
# #####2.6 Contract and Payment

# %% [markdown]
# ######2.6.1- Contract

# %%
df['contract'].value_counts(normalize = True)
# Out:
# Month-to-month    0.551052
# Two year          0.239619
# One year          0.209329
# Name: contract, dtype: float64

# %%
exploring_addtional_services('contract')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('contract')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df, x = 'contract', y = 'monthlycharges', color = 'churn', height = 500, width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Customers who contract month to month are more probable to churn. Unlike those who contract every two year

# %% [markdown]
# ######2.6.2- Paperless Billing

# %%
df['paperlessbilling'].value_counts(normalize = True)
# Out:
# Yes    0.592719
# No     0.407281
# Name: paperlessbilling, dtype: float64

# %%
exploring_addtional_services('paperlessbilling')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('paperlessbilling')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. Customers with paperless billing are more probable to churn

# %% [markdown]
# ######2.6.3- Payment Method

# %%
df['paymentmethod'].value_counts(normalize = True)
# Out:
# Electronic check             0.336320
# Mailed check                 0.228100
# Bank transfer (automatic)    0.219283
# Credit card (automatic)      0.216297
# Name: paymentmethod, dtype: float64

# %%
exploring_addtional_services('paymentmethod')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exploring_addtional_services_churn('paymentmethod')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df, x = 'paymentmethod', y = 'monthlycharges', color = 'churn', height = 500, width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the plots above we can conclude that:
# 1. The preferred payment method is Electronic check with around 35% of customers.This method also has a very high churn rate.
# 2. Mailed checks have lower charges.

# %%
df
# Out:
#       gender seniorcitizen partner dependents  tenure phoneservice  \
# 0     Female             0     Yes         No       1           No
# 1       Male             0      No         No      34          Yes
# 2       Male             0      No         No       2          Yes
# 3       Male             0      No         No      45           No
# 4     Female             0      No         No       2          Yes
# ...      ...           ...     ...        ...     ...          ...
# 7038    Male             0     Yes        Yes      24          Yes
# 7039  Female             0     Yes        Yes      72          Yes
# 7040  Female             0     Yes        Yes      11           No
# 7041    Male             1     Yes         No       4          Yes
# 7042    Male             0      No         No      66          Yes
#
#          multiplelines internetservice onlinesecurity onlinebackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
def binary_map(feature):
    return feature.map({'Yes':1, 'No':0})

df['gender'] = df['gender'].map({'Male':1, 'Female':0})

#Encoding other binary category
binary_list = ['partner', 'dependents', 'phoneservice', 'paperlessbilling']
df[binary_list] = df[binary_list].apply(binary_map)

#Encoding the other categoric features with more than two categories
df = pd.get_dummies(df, drop_first=True)
# Out:
# <ipython-input-91-b5aaf3bbda15>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#       gender  partner  dependents  tenure  phoneservice  paperlessbilling  \
# 0          0        1           0       1             0                 1
# 1          1        0           0      34             1                 0
# 2          1        0           0       2             1                 1
# 3          1        0           0      45             0                 0
# 4          0        0           0       2             1                 1
# ...      ...      ...         ...     ...           ...               ...
# 7038       1        1           1      24             1                 1
# 7039       0        1           1      72             1                 1
# 7040       0        1           1      11             0                 1
# 7041       1        1           0       4             1                 1
# 7042       1        0           0      66             1                 1
#
#       monthlycharges  totalcharges  churn  seniorcitizen_1  \
# ...

# %% [markdown]
# #Correlation between Features

# %%
plt.figure(figsize=(20, 12))
corr = df.corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, linewidths=.2, annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 12))
corr = df.apply(lambda x: pd.factorize(x)[0]).corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, linewidths=.2, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Model

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

#Change variable name separators to '_'
all_columns = [column.replace(" ", "").replace("(", "").replace(")", "").replace("-", "") for column in df.columns]

#Effect the change to the dataframe column names
df.columns = all_columns

#Prepare it for the GLM formula
glm_columns = [e for e in all_columns if e not in ['churn']]
glm_columns = ' + '.join(map(str, glm_columns))

#Fiting it to the Generalized Linear Model
glm_model = smf.glm(formula=f'churn ~ {glm_columns}', data=df, family=sm.families.Binomial())
res = glm_model.fit()
print(res.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  churn   No. Observations:                 7032
# Model:                            GLM   Df Residuals:                     7008
# Model Family:                Binomial   Df Model:                           23
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2913.1
# Date:                Sat, 11 Mar 2023   Deviance:                       5826.3
# Time:                        06:56:22   Pearson chi2:                 8.03e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):             0.2807
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
df['tenure'] = sc.fit_transform(df[['tenure']])
df['monthlycharges'] = sc.fit_transform(df[['monthlycharges']])
df['totalcharges'] = sc.fit_transform(df[['totalcharges']])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df
# Out:
#       gender  partner  dependents    tenure  phoneservice  paperlessbilling  \
# 0          0        1           0  0.000000             0                 1
# 1          1        0           0  0.464789             1                 0
# 2          1        0           0  0.014085             1                 1
# 3          1        0           0  0.619718             0                 0
# 4          0        0           0  0.014085             1                 1
# ...      ...      ...         ...       ...           ...               ...
# 7038       1        1           1  0.323944             1                 1
# 7039       0        1           1  1.000000             1                 1
# 7040       0        1           1  0.140845             0                 1
# 7041       1        1           0  0.042254             1                 1
# 7042       1        0           0  0.915493             1                 1
#
# ...

# %%
from sklearn.model_selection import train_test_split
X = df.drop('churn', axis=1)
y = df['churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
print(X.shape)
# Out:
# (7032, 30)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix  

def scores(alg_name, y_test, y_pred):
        print(alg_name)
        acc_score = accuracy_score(y_test, y_pred)
        print(f"accuracy: {acc_score*100} %")
        pre_score = precision_score(y_test, y_pred)
        print(f"precision: {pre_score*100} %")
        rec_score = recall_score(y_test, y_pred)
        print(f"recall: {rec_score*100} %")
        f_score = f1_score(y_test, y_pred, average='weighted')
        print(f"f1_score: {f_score*100} %")
        print("")
        cm = confusion_matrix(y_test, y_pred)  
        plt.figure(figsize=(6, 6))
        sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.show()
        return acc_score

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression(random_state=42)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

lr_acc = scores("Logistic Regression",y_test,y_pred)
# Out:
# Logistic Regression
# accuracy: 81.27962085308057 %
# precision: 66.04166666666667 %
# recall: 57.74134790528234 %
# f1_score: 80.85436799018186 %

# %%
from sklearn.svm import SVC

model_1 = SVC(random_state=42)
model_1.fit(X_train,y_train)
y_pred_1 = model_1.predict(X_test)

svc_acc = scores("SVC",y_test,y_pred_1)
# Out:
# SVC
# accuracy: 80.52132701421802 %
# precision: 66.42857142857143 %
# recall: 50.81967213114754 %
# f1_score: 79.61121682882954 %

# %%
from sklearn.naive_bayes import GaussianNB  

model_2 = GaussianNB()
model_2.fit(X_train, y_train)
y_pred_2 = model_2.predict(X_test) 

nb_acc = scores("Naive Bayes",y_test,y_pred_2)
# Out:
# Naive Bayes
# accuracy: 65.260663507109 %
# precision: 41.91564147627416 %
# recall: 86.88524590163934 %
# f1_score: 67.2861386096018 %

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

logit = roc_auc_score(y_test,model.predict(X_test))
fpr,tpr,thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr,tpr, label='Logistic Regression (area = %0.2f)' % logit)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Reciever Operating Characteristics')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

logit = roc_auc_score(y_test,model_2.predict(X_test))
fpr,tpr,thresholds = roc_curve(y_test, model_2.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr,tpr, label='Naive Bayes (area = %0.2f)' % logit)
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Reciever Operating Characteristics')
plt.legend(loc="lower right")
plt.show()
